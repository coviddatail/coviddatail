# %%
import requests

# %%
import openpyxl

# %%
workbook = openpyxl.load_workbook('population.xlsx')

# %%
workbook.worksheets[1]
# Out:
# <Worksheet "2000">

# %%
import pandas as pd

# %%
pd.read_excel('population.xlsx', sheet_name='2000')
# Out:
#                                             Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0    אוכלוסייה, לפי מחוז ונפה, קבוצת אוכלוסייה, מין...        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                      הנתונים מוצגים במספרים מוחלטים.        NaN        NaN
# 3                                                  NaN        NaN        NaN
# 4                  .. = הנתונים קטנים מ-3 או שווים ל-3        NaN        NaN
# ..                                                 ...        ...        ...
# 191                                                NaN        NaN        NaN
# 192                                                NaN        NaN        NaN
# 193                                                NaN        NaN    באר שבע
# 194                                                NaN        NaN        NaN
# 195                                                NaN        NaN        NaN
#
# ...

# %%
fr = _

# %%
from bokeh_frame import charts

# %%
# Out:
#                                            Unnamed: 0    Unnamed: 1  \
# 0   אוכלוסייה, לפי מחוז ונפה, קבוצת אוכלוסייה, מין...           NaN
# 1                                                 NaN           NaN
# 2                     הנתונים מוצגים במספרים מוחלטים.           NaN
# 3                                                 NaN           NaN
# 4                 .. = הנתונים קטנים מ-3 או שווים ל-3           NaN
# 5                                                 NaN           NaN
# 6   אזהרה: בשימוש בנתונים יש להביא בחשבון שככל שהמ...           NaN
# 7                                                 NaN           NaN
# 8                                     קבוצת אוכלוסייה          מחוז
# 9                                                 NaN           NaN
# 10                                               סה"כ        סך הכל
# 11                                                NaN           NaN
# 12                                                NaN           NaN
# ...

# %%
charts.Line.simple(
fr.iloc[13:,4:].convert_dtypes().sum(axis=1))
# Out:
# /tmp/ipykernel_85/2480241632.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   fr.iloc[13:,4:].convert_dtypes().sum(axis=1))
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>
# {'X': '@X', 'Y': '@Y'}
#   <div class="bk-root" id="ef0faa99-7461-41c3-b7f1-f0ad07902fd9" data-root-id="1004"></div>
# Figure(id='1004', ...)

# %%
fr.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
# ...
